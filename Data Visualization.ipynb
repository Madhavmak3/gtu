# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in d:\software\anaconda3\lib\site-packages (3.5.2)
# Requirement already satisfied: cycler>=0.10 in d:\software\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\software\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in d:\software\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: numpy>=1.17 in d:\software\anaconda3\lib\site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: pillow>=6.2.0 in d:\software\anaconda3\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in d:\software\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\software\anaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\software\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\software\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as pit
import numpy as np
x=[23,12,44,34,555]
y=[55,2,51,44,2]
z=[23,44,33,55,66]
pit.plot(x,y,z)
pit.xlabel('x-axis')
pit.ylabel('y-axis')
pit.title('My first Graph')
pit.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([2,3,5,3])

plt.plot(ypoints,marker = 'x')
plt.plot(ypoints,color='#90EE90')
plt.plot(ypoints,linestyle = "dashdot")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x= np.arange(2,10,0.5)
y= np.sin(x)

plt.figure(figsize=(24,10))
plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([2,3,5,5])
y=np.array([3,4,5,6])
plt.subplot(3,3,1)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(3,3,2)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(3,3,3)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(3,3,4)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(3,3,5)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(3,3,6)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(3,3,7)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,50,40])
plt.subplot(3,3,(8,9))
plt.plot(x,y)

# %%
import numpy as np
import matplotlib.pyplot as plt

x=[3,3,4,5,3]
y=[42,5,24,4,4]
plt.bar(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x=[2,3,4,5,6,5,6,6,7,3]
y=[3,6,5,2,2,6,2,5,6,3]
plt.scatter(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x=[1,2,34,34,35,75,75,84,56]
y=[3,4,34,53,76,58,86,86,97]

plt.plot(x,y,'g')
plt.xlabel('x')
plt.ylabel('y')

plt.tick_params(axis='x',labelsize=18,labelrotation=-60,labelcolor='blue')
plt.tick_params(axis='y',labelsize=12,labelrotation=20,labelcolor='black')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

y1=[3,6,6,7]
y2=[1,4,5,6]

plt.plot(y1)
plt.plot(y2)

plt.legend(["blue","green"], loc ="lower right")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

data=np.random.normal(324,42,5454)

plt.hist(data)
plt.show()

plt.hist(data,bins=30)
plt.show()

# %%
x= np.linspace(0,20,100)
fig, ax= plt.subplots()
ax.plot(x, np.cos(x))
ax.axis('equal')

ax.annotate('local maximum' , xy=(6.28,1), xytext = (10,4) , arrowprops = dict(facecolor= 'black',shrink=0.05))
ax.annotate('local minimum', xy=(5*np.pi,-1), xytext=(2,-6), arrowprops=dict(arrowstyle="->",connectionstyle="angle3,angleA=0,angleB=90"));

# %%
import numpy as np
import matplotlib.pyplot as plt
w=4
h=3
d=70
plt.figure(figsize=(w,h),dpi=d)
plt.axis([0,5,0,5])
x=[0,3,5]
y=[1,4,3.5]
label_x=1
label_y=4
arrow_x=3
arrow_y=4

arrow_properties=dict(facecolor="black",width=1,headwidth=4,shrink=1)
plt.annotate("maximum",xy=(arrow_x,arrow_y),xytext=(label_x,label_y),arrowprops=arrow_properties)
plt.plot(x,y)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
fig=plt.figure()
ax=plt.axes(projection='3d')

z=np.linspace(1,3,100)
x=z*np.sin(15*z)
y=z*np.cos(15*z)

ax.plot3D(x,y,z,'green')
ax.set_title('3D line plot')
plt.show()

# %%
cars=['audi','bmw','ford','tesla','jaguar','mercedes']
data=[32,324,235,234,235,234]
fig=plt.figure(figsize=(10,7))
plt.pie(data,labels=cars)
plt.show()
